# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedant-Trivedi/Project-0/blob/main/EXP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Vedant Trivedi - 25070123121
# ##Exp1: Introduction to Python

# %%
x,y,z = "apple","cherry","orange"
print(x,x,y,sep="\n")
# Out:
# apple
# apple
# cherry

# %%
x,y,w,z=2,2.5,"anurag",True
print(type(x),type(y),type(w),type(z),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("sum =",a+b,"\n")
print("sub =",a-b,"\n")
print("mult =",a*b,"\n")
print("div =",a/b,"\n")
print("exp =",a**b,"\n")
# Out:
# sum = 15
#
# sub = 5
#
# mult = 50
#
# div = 2.0
#
# exp = 100000

# %%
a=float(input("Enter first number: "))
b=float(input("Enter second number: "))
print("sum =",a+b,"\n","sub =",a-b,"\n","mult =",a*b,"\n","div =",a/b,"\n","exp =",a**b,"\n")
# Out:
# Enter first number: 44
# Enter second number: 3
# sum = 47.0
#  sub = 41.0
#  mult = 132.0
#  div = 14.666666666666666
#  exp = 85184.0

# %%
import math
print(math.log10(10))
# Out:
# 1.0

# %%
import math
x = input ("enter radius = ")
print("area = ",math.pi*float(x)**2)
# Out:
# enter radius = 4
# area =  50.26548245743669

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
if a>b:
    print(a,"(a) is greater than (b)",b)
elif b>a:
    print(b,"(b) is greater than (a)",a)
else:
    print(a,"(a) is equal to (b)",b)
# Out:
# Enter first number: 3
# Enter second number: 4
# 4.0 (b) is greater than (a) 3.0

# %%
def add(x, y):
    return x + y
def subtract(x, y):
    return x - y
def multiply(x, y):
    return x * y
def divide(x, y):
    if y == 0:
        return "Error! Division by zero."
    return x / y
def calculator():
    print("--- Simple Python Calculator ---")
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    choice = input("Enter choice (1/2/3/4): ")
    if choice in ['1', '2', '3', '4']:
        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input. Please enter numeric values.")
            return
        if choice == '1':
            print(f"{num1} + {num2} = {add(num1, num2)}")
        elif choice == '2':
            print(f"{num1} - {num2} = {subtract(num1, num2)}")
        elif choice == '3':
            print(f"{num1} * {num2} = {multiply(num1, num2)}")
        elif choice == '4':
            result = divide(num1, num2)
            print(f"{num1} / {num2} = {result}")
    else:
        print("Invalid Input")
calculator()
# Out:
# --- Simple Python Calculator ---
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Enter choice (1/2/3/4): 3
# Enter first number: 4
# Enter second number: 4
# 4.0 * 4.0 = 16.0
